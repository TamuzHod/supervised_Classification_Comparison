# %%
import dota2api
from dota2api.src.exceptions import APIError, APITimeoutError
import csv
from multiprocessing import Pool
import time
import sys
import numpy as np

# %%
def getMatchInfo( api, matchId ):
    for retries in range(3):
        try:
            match = api.get_match_details(match_id=matchId)
            break
        except APIError as e:
            #print(e.msg)
            raise APIError('Getting match ' + str(matchId) + ' Failed')
        except Exception as e:
           # print(sys.exc_info())
            if retries == 2:
                raise APIError('Getting match ' + str(matchId) + ' Failed')
            else:
                time.sleep(120)
    
    if match['human_players'] != 10 or len(match['players']) != 10:
        raise APIError('Bad number of players')
    if 'radiant_win' not in match.keys():
        raise APIError('Match not completed')
    matchRow = [0]*15
    matchRow[0] = matchId
    if match['radiant_win']: # eg True
        matchRow[1] = 1
    else:
        matchRow[1] = -1
    if('game_mode' not in match or 'lobby_type' not in match):
        raise APIError('match ' + str(matchId) + ' does not contain type')
        
    matchRow[2] = match['cluster'] # eg 227 -> translates to Europe West?
    matchRow[3] = match['game_mode'] # eg Captains Mode
    matchRow[4] = match['lobby_type'] # eg Ranked
    for i in range(10):
        matchRow[5 + i] = match['players'][i]['hero_id'] # eg 5

    return matchRow

# %%
def serialLoop( api, matchId, stopNum, writer ):
    while stopNum > 0:
        try:
            matchInfo = getMatchInfo( api, matchId )
            writer.writerow(matchInfo)
            stopNum -= 1
          #  print("Got " + str(matchId) + ", Need " + str(stopNum) + " more")
        except APIError as e:
           # print(e.msg)
            x=0
        finally:
            matchId -= 1

# %%
def getMatchStar( args ):
    try:
        match = getMatchInfo( args[0], args[1] )
        print("Match " + str(args[1]) + " successful")
        return match
    except APIError as e:
        print (e.msg)
    return []

# %%
     
def parallelLoop( api, matchId, stopNum, writer ):
    p = Pool(4)

    matchList = ( [ (api, matchId - x ) for x in range(2*stopNum) ] )
    for x in p.map(getMatchStar, matchList):
        if len(x) != 0:
            writer.writerow( x )
    p.terminate()

# %%
if __name__=="__main__":
    api = dota2api.Initialise('4515D85FAC69BE2FC86BE529A03D234E')
    matchId = 5283290278
    ### matchSeqNum = 2242825642
    stopNum = 10000
    batch_num = 1000
    batch_size = stopNum/batch_num
    for i in range(700,batch_num):
        print('batch ', i)
        outFile = open('temp_data/dotaMatch_'+str(i)+'.csv', 'a')
        writer = csv.writer(outFile)
        serialLoop( api, matchId - i*batch_size, batch_size, writer )
        outFile.close()
# Out:
# batch  700
# batch  701
# batch  702
# batch  703
# batch  704
# batch  705
# batch  706
# batch  707
# batch  708
# batch  709
# batch  710
# batch  711
# batch  712
# batch  713
# batch  714
# batch  715
# batch  716
# batch  717
# batch  718
# batch  719
# batch  720
# batch  721
# batch  722
# batch  723
# batch  724
# batch  725
# batch  726
# batch  727
# batch  728
# batch  729
# batch  730
# batch  731
# batch  732
# batch  733
# batch  734
# batch  735
# batch  736
# batch  737
# batch  738
# batch  739
# batch  740
# batch  741
# batch  742
# batch  743
# batch  744
# batch  745
# batch  746
# batch  747
# batch  748
# batch  749
# batch  750
# batch  751
# batch  752
# batch  753
# batch  754
# batch  755
# batch  756
# batch  757
# batch  758
# batch  759
# batch  760
# batch  761
# batch  762
# batch  763
# batch  764
# batch  765
# batch  766
# batch  767
# batch  768
# batch  769
# batch  770
# batch  771
# batch  772
# batch  773
# batch  774
# batch  775
# batch  776
# batch  777
# batch  778
# batch  779
# batch  780
# batch  781
# batch  782
# batch  783
# batch  784
# batch  785
# batch  786
# batch  787
# batch  788
# batch  789
# batch  790
# batch  791
# batch  792
# batch  793
# batch  794
# batch  795
# batch  796
# batch  797
# batch  798
# batch  799
# batch  800
# batch  801
# batch  802
# batch  803
# batch  804
# batch  805
# batch  806
# batch  807
# batch  808
# batch  809
# batch  810
# batch  811
# batch  812
# batch  813
# batch  814
# batch  815
# batch  816
# batch  817
# batch  818
# batch  819
# batch  820
# batch  821
# batch  822
# batch  823
# batch  824
# batch  825
# batch  826
# batch  827
# batch  828
# batch  829
# batch  830
# batch  831
# batch  832
# batch  833
# batch  834
# batch  835
# batch  836
# batch  837
# batch  838
# batch  839
# batch  840
# batch  841
# batch  842
# batch  843
# batch  844
# batch  845
# batch  846
# batch  847
# batch  848
# batch  849
# batch  850
# batch  851
# batch  852
# batch  853
# batch  854
# batch  855
# batch  856
# batch  857
# batch  858
# batch  859
# batch  860
# batch  861
# batch  862
# batch  863
# batch  864
# batch  865
# batch  866
# batch  867
# batch  868
# batch  869
# batch  870
# batch  871
# batch  872
# batch  873
# batch  874
# batch  875
# batch  876
# batch  877
# batch  878
# batch  879
# batch  880
# batch  881
# batch  882
# batch  883
# batch  884
# batch  885
# batch  886
# batch  887
# batch  888
# batch  889
# batch  890
# batch  891
# batch  892
# batch  893
# batch  894
# batch  895
# batch  896
# batch  897
# batch  898
# batch  899
# batch  900
# batch  901
# batch  902
# batch  903
# batch  904
# batch  905
# batch  906
# batch  907
# batch  908
# batch  909
# batch  910
# batch  911
# batch  912
# batch  913
# batch  914
# batch  915
# batch  916
# batch  917
# batch  918
# batch  919
# batch  920
# batch  921
# batch  922
# batch  923
# batch  924
# batch  925
# batch  926
# batch  927
# batch  928
# batch  929
# batch  930
# batch  931
# batch  932
# batch  933
# batch  934
# batch  935
# batch  936
# batch  937
# batch  938
# batch  939
# batch  940
# batch  941
# batch  942
# batch  943
# batch  944
# batch  945
# batch  946
# batch  947
# batch  948
# batch  949
# batch  950
# batch  951
# batch  952
# batch  953
# batch  954
# batch  955
# batch  956
# batch  957
# batch  958
# batch  959
# batch  960
# batch  961
# batch  962
# batch  963
# batch  964
# batch  965
# batch  966
# batch  967
# batch  968
# batch  969
# batch  970
# batch  971
# batch  972
# batch  973
# batch  974
# batch  975
# batch  976
# batch  977
# batch  978
# batch  979
# batch  980
# batch  981
# batch  982
# batch  983
# batch  984
# batch  985
# batch  986
# batch  987
# batch  988
# batch  989
# batch  990
# batch  991
# batch  992
# batch  993
# batch  994
# batch  995
# batch  996
# batch  997
# batch  998
# batch  999

# %%
import os
import glob
import pandas as pd
os.chdir("./temp_data")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('dotaMatch_*.{}'.format(extension))]

# %%
names = ['match_id', 'team_won', 'cluster', 'game_mode', 'game_type'] + ['hero_' + str(x) for x in np.arange(1, 113)]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f, names=names) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "../combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
combined_csv
# Out:
#         match_id  team_won  cluster  game_mode  game_type  hero_1  hero_2  \
# 0   5.283290e+09         1      156          4          0      19      96
# 1   5.283290e+09         1      227         22          7      26      40
# 2   5.283290e+09         1      236         22          7      95      40
# 3   5.283290e+09         1      225         22          7     120      37
# 4   5.283290e+09         1      153         22          7      44       6
# ..           ...       ...      ...        ...        ...     ...     ...
# 5   5.283280e+09        -1      131         22          7      70      64
# 6   5.283280e+09         1      187         22          7      88      74
# 7   5.283280e+09         1      155         22          7      74     101
# 8   5.283280e+09        -1      227         22          7     128      30
# 9   5.283280e+09        -1      202         22          7      25       2
#
#     hero_3  hero_4  hero_5  hero_6  hero_7  hero_8  hero_9  hero_10
# 0       41      54      36      95      59     114      32       49
# 1       93      49     106      32       9     121      63       17
# 2        2      25      76      74      49      93      26       99
# 3        6       2      14      86      35      93      29       58
# 4       96      84      14      19      25      20       8       15
# ..     ...     ...     ...     ...     ...     ...     ...      ...
# 5       95      32      84       8      28      30      74       51
# 6       70      53      54       7      14       6      86       11
# 7       80      83      42      26      97      44      31       60
# 8       11       8     129      93     108      22      31       14
# 9       44      74      26       1      13      22      50       84
#
# [22318 rows x 15 columns]

# %%
import pandas as pd

# %%
train_dota = pd.read_csv("../combined_csv.csv")

# %%
train_dota
# Out:
#            match_id  team_won  cluster  game_mode  game_type  hero_1  hero_2  \
# 0      5.283290e+09         1      156          4          0      19      96
# 1      5.283290e+09         1      227         22          7      26      40
# 2      5.283290e+09         1      236         22          7      95      40
# 3      5.283290e+09         1      225         22          7     120      37
# 4      5.283290e+09         1      153         22          7      44       6
# ...             ...       ...      ...        ...        ...     ...     ...
# 22313  5.283280e+09        -1      131         22          7      70      64
# 22314  5.283280e+09         1      187         22          7      88      74
# 22315  5.283280e+09         1      155         22          7      74     101
# 22316  5.283280e+09        -1      227         22          7     128      30
# 22317  5.283280e+09        -1      202         22          7      25       2
#
#        hero_3  hero_4  hero_5  hero_6  hero_7  hero_8  hero_9  hero_10
# 0          41      54      36      95      59     114      32       49
# 1          93      49     106      32       9     121      63       17
# 2           2      25      76      74      49      93      26       99
# 3           6       2      14      86      35      93      29       58
# 4          96      84      14      19      25      20       8       15
# ...       ...     ...     ...     ...     ...     ...     ...      ...
# 22313      95      32      84       8      28      30      74       51
# 22314      70      53      54       7      14       6      86       11
# 22315      80      83      42      26      97      44      31       60
# 22316      11       8     129      93     108      22      31       14
# 22317      44      74      26       1      13      22      50       84
#
# [22318 rows x 15 columns]

# %%
names

# %%
5283290278 - 10000

# %%
match['radiant_score']

# %%
for retries in range(3):
    try:
        match = api.get_match_details(match_id=matchId)
        break
    except APIError as e:
        #print(e.msg)
        raise APIError('Getting match ' + str(matchId) + ' Failed')
    except Exception as e:
       # print(sys.exc_info())
        if retries == 2:
            raise APIError('Getting match ' + str(matchId) + ' Failed')
        else:
            time.sleep(120)

if match['human_players'] != 10 or len(match['players']) != 10:
    raise APIError('Bad number of players')
if 'radiant_win' not in match.keys():
    raise APIError('Match not completed')
matchRow = [0]*15
matchRow[0] = matchId
if match['radiant_win']: # eg True
    matchRow[1] = 1
else:
    matchRow[1] = -1
if('game_mode' not in match or 'lobby_type' not in match):
    raise APIError('match ' + str(matchId) + ' does not contain type')

# %%
match
# Out:
# {'players': [{'account_id': 1038188915,
#    'player_slot': 0,
#    'hero_id': 19,
#    'item_0': 210,
#    'item_1': 63,
#    'item_2': 152,
#    'item_3': 11,
#    'item_4': 252,
#    'item_5': 73,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 331,
#    'kills': 8,
#    'deaths': 7,
#    'assists': 15,
#    'leaver_status': 0,
#    'last_hits': 136,
#    'denies': 6,
#    'gold_per_min': 443,
#    'xp_per_min': 708,
#    'level': 23,
#    'hero_damage': 31640,
#    'tower_damage': 4950,
#    'hero_healing': 0,
#    'gold': 2626,
#    'gold_spent': 13925,
#    'scaled_hero_damage': 18394,
#    'scaled_tower_damage': 2951,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5108, 'time': 118, 'level': 1},
#     {'ability': 5106, 'time': 292, 'level': 2},
#     {'ability': 5107, 'time': 353, 'level': 3},
#     {'ability': 5106, 'time': 457, 'level': 4},
#     {'ability': 5106, 'time': 521, 'level': 5},
#     {'ability': 5107, 'time': 615, 'level': 6},
#     {'ability': 5109, 'time': 745, 'level': 7},
#     {'ability': 5107, 'time': 836, 'level': 8},
#     {'ability': 5107, 'time': 862, 'level': 9},
#     {'ability': 5939, 'time': 1005, 'level': 10},
#     {'ability': 5106, 'time': 1075, 'level': 11},
#     {'ability': 5109, 'time': 1159, 'level': 12},
#     {'ability': 5108, 'time': 1219, 'level': 13},
#     {'ability': 6937, 'time': 1286, 'level': 14},
#     {'ability': 6153, 'time': 1461, 'level': 15},
#     {'ability': 6937, 'time': 1643, 'level': 16},
#     {'ability': 5109, 'time': 1915, 'level': 17},
#     {'ability': 6080, 'time': 2004, 'level': 18}],
#    'hero_name': 'Tiny',
#    'item_0_name': "Heaven's Halberd",
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Shadow Blade',
#    'item_3_name': 'Quelling Blade',
#    'item_4_name': 'Echo Sabre',
#    'item_5_name': 'Bracer',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 1,
#    'hero_id': 96,
#    'item_0': 214,
#    'item_1': 11,
#    'item_2': 36,
#    'item_3': 242,
#    'item_4': 53,
#    'item_5': 279,
#    'backpack_0': 113,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 0,
#    'kills': 4,
#    'deaths': 11,
#    'assists': 21,
#    'leaver_status': 0,
#    'last_hits': 56,
#    'denies': 5,
#    'gold_per_min': 362,
#    'xp_per_min': 480,
#    'level': 19,
#    'hero_damage': 11363,
#    'tower_damage': 2837,
#    'hero_healing': 0,
#    'gold': 2376,
#    'gold_spent': 10520,
#    'scaled_hero_damage': 8393,
#    'scaled_tower_damage': 1541,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5515, 'time': 184, 'level': 1},
#     {'ability': 5516, 'time': 311, 'level': 2},
#     {'ability': 5514, 'time': 424, 'level': 3},
#     {'ability': 5516, 'time': 569, 'level': 4},
#     {'ability': 5516, 'time': 815, 'level': 5},
#     {'ability': 5517, 'time': 964, 'level': 6},
#     {'ability': 5516, 'time': 1076, 'level': 7},
#     {'ability': 5514, 'time': 1328, 'level': 8},
#     {'ability': 5514, 'time': 1442, 'level': 9},
#     {'ability': 5918, 'time': 1517, 'level': 10},
#     {'ability': 5514, 'time': 1752, 'level': 11},
#     {'ability': 5517, 'time': 1831, 'level': 12},
#     {'ability': 5515, 'time': 1886, 'level': 13},
#     {'ability': 5515, 'time': 1921, 'level': 14},
#     {'ability': 7372, 'time': 2008, 'level': 15},
#     {'ability': 5515, 'time': 2012, 'level': 16},
#     {'ability': 5517, 'time': 2215, 'level': 17}],
#    'hero_name': 'Centaur Warrunner',
#    'item_0_name': 'Tranquil Boots',
#    'item_1_name': 'Quelling Blade',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Crimson Guard',
#    'item_4_name': 'Reaver',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 2,
#    'hero_id': 41,
#    'item_0': 147,
#    'item_1': 158,
#    'item_2': 75,
#    'item_3': 63,
#    'item_4': 0,
#    'item_5': 11,
#    'backpack_0': 16,
#    'backpack_1': 16,
#    'backpack_2': 0,
#    'item_neutral': 376,
#    'kills': 10,
#    'deaths': 2,
#    'assists': 21,
#    'leaver_status': 0,
#    'last_hits': 182,
#    'denies': 17,
#    'gold_per_min': 493,
#    'xp_per_min': 766,
#    'level': 24,
#    'hero_damage': 24800,
#    'tower_damage': 8476,
#    'hero_healing': 0,
#    'gold': 4116,
#    'gold_spent': 13625,
#    'scaled_hero_damage': 17100,
#    'scaled_tower_damage': 4137,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5182, 'time': 186, 'level': 1},
#     {'ability': 5184, 'time': 268, 'level': 2},
#     {'ability': 5182, 'time': 381, 'level': 3},
#     {'ability': 5184, 'time': 484, 'level': 4},
#     {'ability': 5182, 'time': 547, 'level': 5},
#     {'ability': 5185, 'time': 649, 'level': 6},
#     {'ability': 5182, 'time': 758, 'level': 7},
#     {'ability': 5184, 'time': 868, 'level': 8},
#     {'ability': 5184, 'time': 1024, 'level': 9},
#     {'ability': 6137, 'time': 1105, 'level': 10},
#     {'ability': 5691, 'time': 1178, 'level': 11},
#     {'ability': 5185, 'time': 1190, 'level': 12},
#     {'ability': 5691, 'time': 1364, 'level': 13},
#     {'ability': 5691, 'time': 1429, 'level': 14},
#     {'ability': 6807, 'time': 1443, 'level': 15},
#     {'ability': 5691, 'time': 1489, 'level': 16},
#     {'ability': 5185, 'time': 1755, 'level': 17},
#     {'ability': 6128, 'time': 1926, 'level': 18}],
#    'hero_name': 'Faceless Void',
#    'item_0_name': 'Manta Style',
#    'item_1_name': 'Mjollnir',
#    'item_2_name': 'Wraith Band',
#    'item_3_name': 'Power Treads',
#    'item_5_name': 'Quelling Blade',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 129505105,
#    'player_slot': 3,
#    'hero_id': 54,
#    'item_0': 127,
#    'item_1': 143,
#    'item_2': 0,
#    'item_3': 112,
#    'item_4': 40,
#    'item_5': 63,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 71,
#    'kills': 6,
#    'deaths': 7,
#    'assists': 15,
#    'leaver_status': 0,
#    'last_hits': 168,
#    'denies': 5,
#    'gold_per_min': 457,
#    'xp_per_min': 669,
#    'level': 23,
#    'hero_damage': 18088,
#    'tower_damage': 4687,
#    'hero_healing': 2370,
#    'gold': 2862,
#    'gold_spent': 13090,
#    'scaled_hero_damage': 9602,
#    'scaled_tower_damage': 2747,
#    'scaled_hero_healing': 820,
#    'ability_upgrades': [{'ability': 5250, 'time': 132, 'level': 1},
#     {'ability': 5251, 'time': 293, 'level': 2},
#     {'ability': 5250, 'time': 404, 'level': 3},
#     {'ability': 5249, 'time': 543, 'level': 4},
#     {'ability': 5250, 'time': 665, 'level': 5},
#     {'ability': 5252, 'time': 767, 'level': 6},
#     {'ability': 5250, 'time': 837, 'level': 7},
#     {'ability': 5251, 'time': 936, 'level': 8},
#     {'ability': 5251, 'time': 978, 'level': 9},
#     {'ability': 5959, 'time': 1083, 'level': 10},
#     {'ability': 5251, 'time': 1089, 'level': 11},
#     {'ability': 5252, 'time': 1153, 'level': 12},
#     {'ability': 5249, 'time': 1209, 'level': 13},
#     {'ability': 5249, 'time': 1269, 'level': 14},
#     {'ability': 5939, 'time': 1478, 'level': 15},
#     {'ability': 5249, 'time': 1659, 'level': 16},
#     {'ability': 5252, 'time': 1886, 'level': 17},
#     {'ability': 5973, 'time': 2015, 'level': 18}],
#    'hero_name': 'Lifestealer',
#    'item_0_name': 'Blade Mail',
#    'item_1_name': 'Skull Basher',
#    'item_3_name': 'Assault Cuirass',
#    'item_4_name': 'Dust of Appearance',
#    'item_5_name': 'Power Treads',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 4,
#    'hero_id': 36,
#    'item_0': 77,
#    'item_1': 50,
#    'item_2': 79,
#    'item_3': 137,
#    'item_4': 108,
#    'item_5': 40,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 288,
#    'kills': 13,
#    'deaths': 6,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 142,
#    'denies': 11,
#    'gold_per_min': 499,
#    'xp_per_min': 813,
#    'level': 25,
#    'hero_damage': 31277,
#    'tower_damage': 2343,
#    'hero_healing': 5381,
#    'gold': 3022,
#    'gold_spent': 14510,
#    'scaled_hero_damage': 14927,
#    'scaled_tower_damage': 1386,
#    'scaled_hero_healing': 2037,
#    'ability_upgrades': [{'ability': 5159, 'time': 115, 'level': 1},
#     {'ability': 5158, 'time': 255, 'level': 2},
#     {'ability': 5158, 'time': 318, 'level': 3},
#     {'ability': 5160, 'time': 424, 'level': 4},
#     {'ability': 5158, 'time': 509, 'level': 5},
#     {'ability': 5161, 'time': 577, 'level': 6},
#     {'ability': 5159, 'time': 696, 'level': 7},
#     {'ability': 5159, 'time': 795, 'level': 8},
#     {'ability': 5160, 'time': 954, 'level': 9},
#     {'ability': 6137, 'time': 990, 'level': 10},
#     {'ability': 5159, 'time': 1073, 'level': 11},
#     {'ability': 5161, 'time': 1221, 'level': 12},
#     {'ability': 5160, 'time': 1289, 'level': 13},
#     {'ability': 7111, 'time': 1432, 'level': 14},
#     {'ability': 5160, 'time': 1437, 'level': 15},
#     {'ability': 5158, 'time': 1442, 'level': 16},
#     {'ability': 5161, 'time': 1580, 'level': 17},
#     {'ability': 350, 'time': 1773, 'level': 18},
#     {'ability': 6703, 'time': 2260, 'level': 19}],
#    'hero_name': 'Necrophos',
#    'item_0_name': 'Null Talisman',
#    'item_1_name': 'Phase Boots',
#    'item_2_name': 'Mekansm',
#    'item_3_name': 'Radiance',
#    'item_4_name': "Aghanim's Scepter",
#    'item_5_name': 'Dust of Appearance',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 128,
#    'hero_id': 95,
#    'item_0': 50,
#    'item_1': 75,
#    'item_2': 36,
#    'item_3': 11,
#    'item_4': 158,
#    'item_5': 216,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 0,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 9,
#    'leaver_status': 0,
#    'last_hits': 87,
#    'denies': 0,
#    'gold_per_min': 292,
#    'xp_per_min': 365,
#    'level': 16,
#    'hero_damage': 14742,
#    'tower_damage': 592,
#    'hero_healing': 0,
#    'gold': 751,
#    'gold_spent': 8690,
#    'scaled_hero_damage': 8044,
#    'scaled_tower_damage': 308,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5508, 'time': 115, 'level': 1},
#     {'ability': 5509, 'time': 278, 'level': 2},
#     {'ability': 5511, 'time': 363, 'level': 3},
#     {'ability': 5509, 'time': 483, 'level': 4},
#     {'ability': 5511, 'time': 594, 'level': 5},
#     {'ability': 5512, 'time': 721, 'level': 6},
#     {'ability': 5508, 'time': 810, 'level': 7},
#     {'ability': 5511, 'time': 961, 'level': 8},
#     {'ability': 5509, 'time': 1159, 'level': 9},
#     {'ability': 5903, 'time': 1325, 'level': 10},
#     {'ability': 5508, 'time': 1369, 'level': 11},
#     {'ability': 5512, 'time': 1438, 'level': 12},
#     {'ability': 5509, 'time': 1651, 'level': 13},
#     {'ability': 5511, 'time': 1694, 'level': 14},
#     {'ability': 6958, 'time': 1766, 'level': 15},
#     {'ability': 5508, 'time': 2033, 'level': 16}],
#    'hero_name': 'Troll Warlord',
#    'item_0_name': 'Phase Boots',
#    'item_1_name': 'Wraith Band',
#    'item_2_name': 'Magic Wand',
#    'item_3_name': 'Quelling Blade',
#    'item_4_name': 'Mjollnir',
#    'item_5_name': 'Enchanted Mango',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 129,
#    'hero_id': 59,
#    'item_0': 151,
#    'item_1': 73,
#    'item_2': 73,
#    'item_3': 63,
#    'item_4': 26,
#    'item_5': 21,
#    'backpack_0': 8,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 0,
#    'kills': 7,
#    'deaths': 8,
#    'assists': 7,
#    'leaver_status': 0,
#    'last_hits': 113,
#    'denies': 28,
#    'gold_per_min': 304,
#    'xp_per_min': 515,
#    'level': 20,
#    'hero_damage': 28110,
#    'tower_damage': 1097,
#    'hero_healing': 0,
#    'gold': 1106,
#    'gold_spent': 8885,
#    'scaled_hero_damage': 18779,
#    'scaled_tower_damage': 656,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5273, 'time': 155, 'level': 1},
#     {'ability': 5272, 'time': 263, 'level': 2},
#     {'ability': 5272, 'time': 327, 'level': 3},
#     {'ability': 7300, 'time': 383, 'level': 4},
#     {'ability': 5273, 'time': 439, 'level': 5},
#     {'ability': 5273, 'time': 508, 'level': 6},
#     {'ability': 5272, 'time': 594, 'level': 7},
#     {'ability': 5274, 'time': 658, 'level': 8},
#     {'ability': 5273, 'time': 732, 'level': 9},
#     {'ability': 5272, 'time': 816, 'level': 10},
#     {'ability': 6405, 'time': 865, 'level': 11},
#     {'ability': 7300, 'time': 952, 'level': 12},
#     {'ability': 7300, 'time': 1153, 'level': 13},
#     {'ability': 7300, 'time': 1275, 'level': 14},
#     {'ability': 6380, 'time': 1330, 'level': 15},
#     {'ability': 5274, 'time': 1412, 'level': 16},
#     {'ability': 5274, 'time': 1639, 'level': 17},
#     {'ability': 6204, 'time': 2084, 'level': 18}],
#    'hero_name': 'Huskar',
#    'item_0_name': 'Armlet of Mordiggian',
#    'item_1_name': 'Bracer',
#    'item_2_name': 'Bracer',
#    'item_3_name': 'Power Treads',
#    'item_4_name': 'Morbid Mask',
#    'item_5_name': 'Ogre Axe',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 840684717,
#    'player_slot': 130,
#    'hero_id': 114,
#    'item_0': 50,
#    'item_1': 75,
#    'item_2': 75,
#    'item_3': 143,
#    'item_4': 166,
#    'item_5': 252,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 378,
#    'kills': 4,
#    'deaths': 7,
#    'assists': 10,
#    'leaver_status': 0,
#    'last_hits': 170,
#    'denies': 16,
#    'gold_per_min': 370,
#    'xp_per_min': 567,
#    'level': 21,
#    'hero_damage': 28427,
#    'tower_damage': 666,
#    'hero_healing': 320,
#    'gold': 842,
#    'gold_spent': 11865,
#    'scaled_hero_damage': 13747,
#    'scaled_tower_damage': 390,
#    'scaled_hero_healing': 191,
#    'ability_upgrades': [{'ability': 5723, 'time': 177, 'level': 1},
#     {'ability': 5716, 'time': 277, 'level': 2},
#     {'ability': 5723, 'time': 390, 'level': 3},
#     {'ability': 5716, 'time': 506, 'level': 4},
#     {'ability': 5723, 'time': 622, 'level': 5},
#     {'ability': 5725, 'time': 708, 'level': 6},
#     {'ability': 5723, 'time': 859, 'level': 7},
#     {'ability': 5716, 'time': 877, 'level': 8},
#     {'ability': 5716, 'time': 956, 'level': 9},
#     {'ability': 5906, 'time': 1076, 'level': 10},
#     {'ability': 5721, 'time': 1080, 'level': 11},
#     {'ability': 5725, 'time': 1194, 'level': 12},
#     {'ability': 5721, 'time': 1339, 'level': 13},
#     {'ability': 5721, 'time': 1401, 'level': 14},
#     {'ability': 5721, 'time': 1567, 'level': 15},
#     {'ability': 6421, 'time': 1636, 'level': 16},
#     {'ability': 5725, 'time': 1836, 'level': 17},
#     {'ability': 6696, 'time': 1895, 'level': 18}],
#    'hero_name': 'Monkey King',
#    'item_0_name': 'Phase Boots',
#    'item_1_name': 'Wraith Band',
#    'item_2_name': 'Wraith Band',
#    'item_3_name': 'Skull Basher',
#    'item_4_name': 'Maelstrom',
#    'item_5_name': 'Echo Sabre',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 131,
#    'hero_id': 32,
#    'item_0': 174,
#    'item_1': 63,
#    'item_2': 181,
#    'item_3': 154,
#    'item_4': 75,
#    'item_5': 75,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 336,
#    'kills': 10,
#    'deaths': 9,
#    'assists': 12,
#    'leaver_status': 0,
#    'last_hits': 73,
#    'denies': 6,
#    'gold_per_min': 332,
#    'xp_per_min': 558,
#    'level': 21,
#    'hero_damage': 23413,
#    'tower_damage': 294,
#    'hero_healing': 0,
#    'gold': 468,
#    'gold_spent': 10800,
#    'scaled_hero_damage': 13685,
#    'scaled_tower_damage': 165,
#    'scaled_hero_healing': 0,
#    'ability_upgrades': [{'ability': 5143, 'time': 126, 'level': 1},
#     {'ability': 5145, 'time': 320, 'level': 2},
#     {'ability': 5143, 'time': 392, 'level': 3},
#     {'ability': 5145, 'time': 547, 'level': 4},
#     {'ability': 5142, 'time': 710, 'level': 5},
#     {'ability': 5144, 'time': 803, 'level': 6},
#     {'ability': 5143, 'time': 1104, 'level': 7},
#     {'ability': 5142, 'time': 1109, 'level': 8},
#     {'ability': 5143, 'time': 1155, 'level': 9},
#     {'ability': 5145, 'time': 1264, 'level': 10},
#     {'ability': 5145, 'time': 1287, 'level': 11},
#     {'ability': 5144, 'time': 1393, 'level': 12},
#     {'ability': 5142, 'time': 1443, 'level': 13},
#     {'ability': 5142, 'time': 1579, 'level': 14},
#     {'ability': 6016, 'time': 1733, 'level': 15},
#     {'ability': 6164, 'time': 1804, 'level': 16},
#     {'ability': 5144, 'time': 2004, 'level': 17},
#     {'ability': 6865, 'time': 2292, 'level': 18}],
#    'hero_name': 'Riki',
#    'item_0_name': 'Diffusal Blade',
#    'item_1_name': 'Power Treads',
#    'item_2_name': 'Orb of Venom',
#    'item_3_name': 'Sange and Yasha',
#    'item_4_name': 'Wraith Band',
#    'item_5_name': 'Wraith Band',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'},
#   {'account_id': 4294967295,
#    'player_slot': 132,
#    'hero_id': 49,
#    'item_0': 73,
#    'item_1': 11,
#    'item_2': 63,
#    'item_3': 1,
#    'item_4': 151,
#    'item_5': 8,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'item_neutral': 334,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 8,
#    'leaver_status': 0,
#    'last_hits': 155,
#    'denies': 12,
#    'gold_per_min': 340,
#    'xp_per_min': 523,
#    'level': 20,
#    'hero_damage': 20782,
#    'tower_damage': 764,
#    'hero_healing': 280,
#    'gold': 546,
#    'gold_spent': 9520,
#    'scaled_hero_damage': 12848,
#    'scaled_tower_damage': 476,
#    'scaled_hero_healing': 152,
#    'ability_upgrades': [{'ability': 5228, 'time': 197, 'level': 1},
#     {'ability': 5226, 'time': 299, 'level': 2},
#     {'ability': 5228, 'time': 378, 'level': 3},
#     {'ability': 5227, 'time': 508, 'level': 4},
#     {'ability': 5228, 'time': 632, 'level': 5},
#     {'ability': 5229, 'time': 733, 'level': 6},
#     {'ability': 5226, 'time': 847, 'level': 7},
#     {'ability': 5226, 'time': 975, 'level': 8},
#     {'ability': 5228, 'time': 1120, 'level': 9},
#     {'ability': 7113, 'time': 1184, 'level': 10},
#     {'ability': 5227, 'time': 1265, 'level': 11},
#     {'ability': 5229, 'time': 1328, 'level': 12},
#     {'ability': 5226, 'time': 1344, 'level': 13},
#     {'ability': 5227, 'time': 1508, 'level': 14},
#     {'ability': 5939, 'time': 1556, 'level': 15},
#     {'ability': 5227, 'time': 1624, 'level': 16},
#     {'ability': 5229, 'time': 1752, 'level': 17},
#     {'ability': 5952, 'time': 2119, 'level': 18}],
#    'hero_name': 'Dragon Knight',
#    'item_0_name': 'Bracer',
#    'item_1_name': 'Quelling Blade',
#    'item_2_name': 'Power Treads',
#    'item_3_name': 'Blink Dagger',
#    'item_4_name': 'Armlet of Mordiggian',
#    'item_5_name': 'Mithril Hammer',
#    'leaver_status_name': 'NONE',
#    'leaver_status_description': 'finished match, no abandon'}],
#  'radiant_win': True,
#  'duration': 2112,
#  'pre_game_duration': 90,
#  'start_time': 1583755723,
#  'match_id': 5283290278,
#  'match_seq_num': 4432958520,
#  'tower_status_radiant': 1974,
#  'tower_status_dire': 0,
#  'barracks_status_radiant': 63,
#  'barracks_status_dire': 0,
#  'cluster': 156,
#  'first_blood_time': 46,
#  'lobby_type': 0,
#  'human_players': 10,
#  'leagueid': 0,
#  'positive_votes': 0,
#  'negative_votes': 0,
#  'game_mode': 4,
#  'flags': 0,
#  'engine': 1,
#  'radiant_score': 42,
#  'dire_score': 33,
#  'lobby_name': 'Public matchmaking',
#  'game_mode_name': 'Single Draft',
#  'cluster_name': 'Southeast Asia'}
